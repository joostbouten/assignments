# %% [markdown]
# # Python assignment
#
# |Name|examnr.|
# |----|-------|
# |Joost Bouten|132978|
# |Twan Vissers|495770|

# %% [markdown]
# # Formula 1
# Joost Bouten and Twan Vissers
#
# # Question
#
# ## Motivation
#
# ## Method
#
# ## Answer
#
# ## Main assumptions
#
# # Importing libraries and data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
driver = pd.read_csv('drivers.csv')
races = pd.read_csv('races.csv')
pitstop = pd.read_csv('pitStops.csv') 
laptimes = pd.read_csv('lapTimes.csv')
results = pd.read_csv('results.csv')

# %%
results.head()
# Out:
#    resultId  raceId  driverId  constructorId  number  grid  position  \
# 0         1      18         1              1    22.0     1       1.0
# 1         2      18         2              2     3.0     5       2.0
# 2         3      18         3              3     7.0     7       3.0
# 3         4      18         4              4     5.0    11       4.0
# 4         5      18         5              1    23.0     3       5.0
#
#   positionText  positionOrder  points  laps     time  milliseconds  \
# 0            1              1    10.0    58  34:50.6     5690616.0
# 1            2              2     8.0    58    5.478     5696094.0
# 2            3              3     6.0    58    8.163     5698779.0
# 3            4              4     5.0    58   17.181     5707797.0
# 4            5              5     4.0    58   18.014     5708630.0
#
#    fastestLap  rank fastestLapTime fastestLapSpeed  statusId
# 0        39.0   2.0        01:27.5           218.3         1
# ...

# %%
sns.lmplot('grid', 'position', data=results, order=1)
#plt.ylim(0,100000)
plt.show()

# %%
driver[driver.number > 0]
# Out:
#      driverId        driverRef  number code    forename      surname  \
# 0           1         hamilton    44.0  HAM       Lewis     Hamilton
# 2           3          rosberg     6.0  ROS        Nico      Rosberg
# 3           4           alonso    14.0  ALO    Fernando       Alonso
# 7           8        raikkonen     7.0  RAI        Kimi   R�_ikk̦nen
# 12         13            massa    19.0  MAS      Felipe        Massa
# 15         16            sutil    99.0  SUT      Adrian        Sutil
# 17         18           button    22.0  BUT      Jenson       Button
# 19         20           vettel     5.0  VET   Sebastian       Vettel
# 153       154         grosjean     8.0  GRO      Romain     Grosjean
# 154       155        kobayashi    10.0  KOB       Kamui    Kobayashi
# 452       842            gasly    10.0  GAS      Pierre        Gasly
# 807       807       hulkenberg    27.0  HUL        Nico  H�_lkenberg
# 812       813        maldonado    13.0  MAL      Pastor    Maldonado
# ...
